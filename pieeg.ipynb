# %% [markdown]
# <a href="https://colab.research.google.com/github/cutestar/PiEEG-16/blob/main/pieeg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Introduction
# Back to [Main Page](https://pieeg.com/)
#
# Thank you so much for your interest for [PiEEG](https://pieeg.com/). Here we presesnt instrucions about devices, how to start. Share your suggestions, comments to  pieeg@pieeg.com

# %% [markdown]
# ##  Liabilities
# PiEEG devices — PiEEG, PiEEG-16, ardEEG, JNEEG...
#
# You are fully responsible for your personal decision to purchase this device and, ultimately, for its safe use. PiEEG devices are not a medical device and has not been certified by any government regulatory agency for use with the human body. Use it at your own risk.
#
# PiEEG devices is subject to the terms outlined below. This evaluation board/kit is exclusively intended for ENGINEERING DEVELOPMENT, DEMONSTRATION, OR EVALUATION PURPOSES and is not deemed a final end-product suitable for general consumer use.
#
# Limitations of Liability:
#
# PiEEG devices are not intended for medical, clinical, or diagnostic purposes, and they are supplied “as is.” PiEEG devices makes no explicit or implied warranties regarding functionality, operability, or use, including, but not limited to, any implied warranties of fitness for a specific purpose or non-infringement.PiEEG devices and absolutely for all devices that have with PiEEG devices connection are engineered to draw power exclusively from low-voltage DC sources, such as batteries, only with 5 V and are not compatible not under any circumstances (for any tasks) with power sources from the grid, power outlets, USB ports, etc.
#
# Individuals handling the product(s) must possess electronics training and adhere to recognized engineering practices. The provided goods are not designed to fulfill all required design, marketing, and manufacturing-related protective considerations, including standard safety and environmental measures present in end products incorporating similar semiconductor components or circuit boards.
#
# This evaluation board/kit does not fall within the scope of European Union directives concerning electromagnetic compatibility, restricted substances (RoHS), recycling (WEEE), FCC, CE, or UL, and thus may not satisfy the technical requirements of these directives or related regulations.
#
# We explicitly disclaim any liability for direct, indirect, consequential, incidental, or special damages, including lost revenues, lost profits, losses resulting from business interruption, or loss of data, irrespective of the form of action or legal theory under which the liability may be asserted, even if awareness of such damages is provided.
# In no event will PiEEG devices be liable to the end user for special, incidental, consequential, exemplary, punitive, or other indirect damages, or for loss of profits, loss of data, or loss of use arising from the manufacture, sale, supply, or failure or delay in supplying the products or services related thereto, whether based upon warranty, contract, tort, strict liability, or otherwise, even if PiEEG devices has been advised of the possibility of such damages or losses. Under no circumstances will PiEEG devices total liability to the end user from any and all causes (including negligence) exceed the total amount paid by the end user for the products.
#
# This is not a device made for consumer home use. The internal electronics are exposed during normal operation to facilitate easy access by developers and professionals. As such, you must be aware of the hazards of operating exposed electronics, and are familiar with standard anti-static procedures for handling bare electrical components, or be prepared to make your own case.
#
# There is no patient isolation circuitry on the device, so again, you must be sure to operate the PiEEG devices and all connected devices from 5V battery power.
#
# You are fully responsible for your personal decision to purchase this device and, ultimately, for its safe use. PiEEG devices are not a medical device and has not been certified by any government regulatory agency for use with the human body. Use it at your own risk.

# %% [markdown]
# [link text](https://)
#
# # How easy eliminate noise during EEG measurement

# %% [markdown]
# Electroencephalography (EEG) is a powerful tool for studying brain activity. PiEEG devices are systems that utilize Raspberry P/Arduino/Jetson Nanoi for EEG data acquisition. However, EEG signals are very delicate and susceptible to various types of noise, including electromagnetic interference. This manual provides guidelines for measuring EEG data using PiEEG while minimizing noise.
#
# For illustrative purposes, let’s take a look at PIEEG, but this concept applies to other boards as well.
#
# To begin, you’ll want to connect the cables and electrode clips. One clip electrode acts as a reference point, against which all EEG measurements, in microvolts, are conducted. In simpler terms, we measure the voltage between the ear and the electrode attachment point on the head. The bias electrode clip is need for eliminating electromagnetic noise, but it is not enough to solve all problems.
#
# **It is necessary pay attentions for the next moments:**
#
# 1. It’s crucial that the device (RaspberryPI, PiEEG, screen, etc.) relies solely on battery power, completely independent from the grid power supply. Avoid using power from a PC, USB, etc.
#
# 2. Opt for wired connections for the keyboard and mouse to minimize wireless interference (not Radio).
#
# 3. Use short as possbile EEG electrode cables
#
# 4. Disable Wi-Fi and Bluetooth on the RaspberryPi.
#
# 5. Position the device away from sources of disruptive noise like computers, Wi-Fi routers, phones, etc.
#
# 6. Ensure there’s effective insulation between the device and its resting surface, such as a rubber mat or even a book.
#
# 7. Ground contact with your feet can introduce noise; consider using foot insulation or avoiding contact with the floor during measurements, and better don’t use metal stool.
#
# 8. Body movements can generate artifacts; hence, it’s vital for electrodes to establish good skin contact (without causing discomfort to the subject) and remain stationary.
#
# 9. Applying gel can enhance the electrode-to-skin contact area, albeit unpleasant, **it helps reduce noise** from electrode micro-movements.
#
# 10. Before starting the measure, confirm that connections between electrodes and skin are good. Better dont corrupt data during measurement, since the band-pass filter takes time to adjust.
#
#
# So, any ideas let us know

# %% [markdown]
# # Electrodes
# Can be used differents type of electrodes with 2.54mm pin pitch. We usually work with dry electrodes Ag/AgCl.
# ![eeg.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Cap
# Can be used any comfortable for you Cap, or some DIY cap, here you can find [instructions](https://www.researchgate.net/publication/369378602_DIY_-Hat_for_measuring_EEG_with_dry_electrodes_for_PiEEG).
# We usually use [Cap](https://pieeg.com/cap-eeg-kit/) is nylon material.
#
# ![cap.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #Power Bank
# All devices must work only from a battery 5V, with power not more than 10000mAh and an output current of at least 3A for JNEEG and piEEG, but not more than 3.5 A, with 5V and not more than 1000mAh for ardEEg. Can be used as one power bank to supply monitors for all PiEEG devices (PiEEG, ArdEEG, JNEEG...)
# USB cable for power supply should short as possible and **sufficient thickness**

# %% [markdown]
# # PiEEG
# PiEEG – Brain-computer interface (EEG, EMG, and ECG bio-signals) is an open-source Raspberry Pi shield that measures biosignals such as those used in electroencephalography (EEG), electromyography (EMG), and electrocardiography (ECG).

# %% [markdown]
# ##  What need equipoment except PiEEG
# Power Bank (not more than 10000mAh and output current at least 3A for JNEEG and PiEEG, not more 1000mah and 5V for ardEEG, current not more 2 A)
# Cable Keyboard
# Cable PC Mouse
# Screen (conenction to power bank)
# RasberryPi4,5(with mciroSD card, connection to power bank)
# EEG cap
# 8 EEG electrodes (dry or wet) and cables
# 2 clips Eelctrodes

# %% [markdown]
# ## How to start. Connections
# Manual is [here](https://github.com/pieeg-club/PiEEG/blob/main/Manual.%20Conenction%20and%20start%20-%20PiEEG1.pdf) for connection and quick start
#
#
# Connect shield to RaspberryPi via GPIO40
# As example you can use this types of Electrodes and Hat - [YouTube](https://www.youtube.com/shorts/RIgRD_4Chhw)
# Connect electrodes and clips electrodes, see the picture
# ![pieeg-pinout-cs_jpg_md-xl.jpg](data:image/jpeg;base64,...)
#
#
# For power supply use only battery with 5V for RaspberrPi and for monitor, as in the picture
#
# ![PiEEG gel.png](data:image/png;base64,...)

# %% [markdown]
# ## How to start. Software
# Scripts available in [GitHub](https://github.com/pieeg-club)
# Read data with band-pass filter and real-time visualisation with[ RaspberryPi5](https://github.com/pieeg-club/GUI/blob/main/1.GUI/1.8_ch_Pi5.py) and [Pi4](https://github.com/pieeg-club/GUI/tree/main/1.GUI)
#
# To save Raw data to excel you can use the next [script for Pi5](https://github.com/pieeg-club/GUI/blob/main/1.GUI/save_data_short_Pi5.py) and for [Pi4](https://github.com/pieeg-club/GUI/blob/main/1.GUI/save_data_short_Pi4.py)
#
#
#
# **Libraries** for  Python 3.11. 2
#
# *   import spidev (pip install spidev)
# *   from RPi import GPIO (pip install RPi.GPIO) for Pi4 only
# *   from matplotlib import pyplot as plt (pip install matplotlib)
# *   from scipy (pip install scipy)
# *   import gpiod (gpiod==1.5.4)  for Pi5 only
#
#
# **Available libraries as example**  for  Python 3.11. 2
# *   matplotlib 3.6.3
# *   spidev 3.5
# *   RPi.GPIO 0.7.1a4  (For Pi4 only)
# *   scipy 1.10.1
#
# 1.8_ch_Pi5.py for gpiod 1.6.3 version (pip install gpiod==1.6.3)
# 1.8_ch_Pi5_gpiod_1_5_4.py for gpiod 1.5.4 version (pip install gpiod==1.5.4)

# %% [markdown]
# ### Software with BrainFlow library for PiEEG
# PiEEG was added to [Brainflow](https://brainflow.readthedocs.io/en/stable/SupportedBoards.html) library
#
# To create such board you need to specify the following board ID and fields of BrainFlowInputParams object:
#
#
# *   BoardIds.PLAYBACK_FILE_BOARD
# * master_board, it should contain board ID of the device used to create playback files
# * file, it should contain full path to recorded file
# * optional: file_aux, use it if your master board has auxiliary preset
# * optional: file_anc, use it if your master board has ancillary preset

# %%
params = BrainFlowInputParams()
params.file = "streamer_default.csv"
params.file_aux = "streamer_aux.csv"
params.master_board = BoardIds.SYNTHETIC_BOARD
board = BoardShim(BoardIds.PLAYBACK_FILE_BOARD, params)

# %% [markdown]
# # PiEEG-16
# PiEEG-16 – Brain-computer interface (EEG, EMG, and ECG bio-signals) is an open-source Raspberry Pi shield that measures biosignals such as those used in electroencephalography (EEG), electromyography (EMG), and electrocardiography (ECG) for 16 channels.

# %% [markdown]
# ##  What need equipoment except PiEEG-16
# Power Bank (not more than 10000mAh) and output current at least 3A and not more than 3.5A
# Cable Keyboard
# Cable PC Mouse
# Screen (conenction to power bank)
# RasberryPi4,5(conenction to power bank)
# EEG cap
# 8 EEG electrodes (dry or wet) and cables
# 2 clips Eelctrodes

# %% [markdown]
# ## How to start. Connections
# Connect shield PiEEG-16 to RaspberryPi via GPIO40
# Manual is [here](https://github.com/pieeg-club/PiEEG/blob/main/Manual.%20Conenction%20and%20start%20-%20PiEEG.pdf) for connection and quick start, same as and for PiEEG
# As example you can use this types of Electrodes and Hat for 16 channel from [PiEEG shop](https://pieeg.com/pieeg-shop/) - [YouTube](https://youtu.be/97dbUigpLjA)
#
# ![IMG_0435.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ## How to start. Software
# Scripts available in [GitHub](https://github.com/pieeg-club)
# Read data with band-pass filter and real-time visualisation with[ RaspberryPi5](https://github.com/pieeg-club/PiEEG-16/blob/main/GUI/1.Graph.Py)
#
# To save Raw data to excel you can use the next [script for Pi5](https://github.com/pieeg-club/PiEEG-16/blob/main/Save_data/1.Save_Data.py)
#
#
# **Libraries** for  Python 3.11. 2
# *   import spidev (pip install spidev)
# *   from RPi import GPIO (pip install RPi.GPIO) #for Pi4 only
# *   from matplotlib import pyplot as plt (pip install matplotlib)
# *   from scipy (pip install scipy)
# *   import gpiod (pip install gpiod==1.5.4) #for Pi5 only
#
#
# **Available libraries as example**  for  Python 3.11. 2
# *   matplotlib 3.6.3
# *   spidev 3.5
# *   RPi.GPIO 0.7.1a4
# *   scipy 1.10.1

# %% [markdown]
# # JNEEG
# Low-cost brain-computer interface with shield JNEEG (Shield for Jetson Nano , nvidia) to measure EEG, EMG, and ECG bio-signals for 8 EEG channels.

# %% [markdown]
# ##  What need equipoment except JNEEG
# *   Power Bank (not more than 10000mAh and output current - 3A)
# *   Cabel Keyboard
# * Cabel PC Mouse
# * Screen (conenction to power bank)
# * Jetson Nano (conenction to power bank)
# * EEG cap
# * 8 EEG electrodes (dry or wet) and cables
# * 2 clips Eelctrodes

# %% [markdown]
# ## How to start. Connections
# Connect shield to Jetson Nano via GPIO40
# Connect electrodes and clips electrodes, see the picture
#
# ![JNEEG.jpg](data:image/jpeg;base64,...)
#
# For power supply use only battery with 5V for Jetson Nano and for monitor, as in the picture

# %% [markdown]
# ## How to start. Software
# Scripts available in GitHub Read data with band-pass filter and real-time visualisation with Jetson Nano for [graph](https://github.com/Ildaron/EEG-with-JetsonNano/blob/master/GUI/1.Graph_real_time.py)
#
# To [save](https://github.com/Ildaron/EEG-with-JetsonNano/blob/master/GUI/2.Save_data.py)  Raw data to excel you can use the next script for Jetson Nano
#
# For power supply use only battery with 5V for JetsonNano and for monitor, as in the picture
# ![JNEEG1 1 –JNEEG, 2 – Clips Electrodes, 3 – EEG cap with, 4 – power battery.jpg](data:image/jpeg;base64,...)
#
# 1 –JNEEG, 2 – Clips Electrodes, 3 – EEG cap with, 4 – power battery

# %% [markdown]
# #ardEEG
# ardEEG shield for Arduino UNO R4 to measure EEG, EMG, and ECG bio-signals

# %% [markdown]
# ##What need equipoment except ardEEG
# Power Bank (not more 300mah and 5V, current not more 2 A)
# Cabel Keyboard
# Cabel PC Mouse
# Arduino UNO R4 (conenction to power bank)
# EEG cap
# 8 EEG electrodes (dry or wet) and cables
# 2 clips Eelctrodes

# %% [markdown]
# ## How to start. Connections
# Connect shield to Arduino via GPIO connect electrodes and clips electrodes, see the picture![gene.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## How to start. Software
# Scripts available in GitHub Read data with band-pass filter and real-time visualisation with Arduino for graph
# Arduino [script](https://github.com/Ildaron/ardEEG/blob/main/software/arduino/1.Send_data_via_wifi.ino), please upload via Arduino IDLE
# and just only write your Wi-Fi  and password
#
# ```
# char ssid[] = "Wifi Name";
# char pass[] = "password";
# ```
#
#
# and Python [script](https://github.com/Ildaron/ardEEG/blob/main/software/python/1.Alpha_real_time.py), for Graph visualisation
#
#
# For power supply use only battery with 5V for JetsonNano and for monitor, as in the picture as in the photo above.
# ![ters.bmp](data:image/bmp;base64,...)
